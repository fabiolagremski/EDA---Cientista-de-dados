# %% [markdown]
# <a href="https://colab.research.google.com/github/fabiolagremski/EDA---Cientista-de-dados/blob/main/Fabiola_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aula - Análise Exploratória de Dados

# %%
import pandas as pd

dados = {'id_familia':[1,2,3,4,5,6,7,8],
         'tipo_casa': ["apartamento","casa","casa","kitnet","sobrado","apartamento","apartamento","casa"],
         'tamanho_casa': ["pequeno","médio","grande","pequeno","médio","grande","grande","pequeno"],
         'n_cartoes': [4,6,6,7,8,7,8,10],
         'tamanho_familia': [2,2,4,4,5,5,6,6],
         'renda_familiar':[14,16,14,17,18,21,17,25],
         'num_automoveis': [1,2,2,1,3,2,1,3],
         'distanciacentro': [22.2,3,31,2,1,12,2,4]}#km

df = pd.DataFrame(dados)
df
# Out:
#    id_familia    tipo_casa tamanho_casa  n_cartoes  tamanho_familia  \
# 0           1  apartamento      pequeno          4                2
# 1           2         casa        médio          6                2
# 2           3         casa       grande          6                4
# 3           4       kitnet      pequeno          7                4
# 4           5      sobrado        médio          8                5
# 5           6  apartamento       grande          7                5
# 6           7  apartamento       grande          8                6
# 7           8         casa      pequeno         10                6
#
#    renda_familiar  num_automoveis  distanciacentro
# 0              14               1             22.2
# 1              16               2              3.0
# 2              14               2             31.0
# 3              17               1              2.0
# 4              18               3              1.0
# 5              21               2             12.0
# 6              17               1              2.0
# 7              25               3              4.0

# %%
dffifa = pd.read_csv('https://www.harve.com.br/praticas/fifaplayers_pt.csv')
dffifa.head()
# Out:
#        id               nome  idade nacionalidade  pontuação geral  potencial  \
# 0  158023           L. Messi     31     Argentina               94         94
# 1   20801  Cristiano Ronaldo     33      Portugal               94         94
# 2  190871          Neymar Jr     26        Brazil               92         93
# 3  193080             De Gea     27         Spain               91         93
# 4  192985       K. De Bruyne     27       Belgium               91         92
#
#                   time    valor remuneração perna de preferência  ...  \
# 0         FC Barcelona  €110.5M       €565K             Esquerda  ...
# 1             Juventus     €77M       €405K              Direita  ...
# 2  Paris Saint-Germain  €118.5M       €290K              Direita  ...
# 3    Manchester United     €72M       €260K              Direita  ...
# 4      Manchester City    €102M       €355K              Direita  ...
#
#    emprestado de  validade do contrato  altura    peso controle de bola  \
# 0             NaN                 2021     5'7  159lbs             96.0
# 1             NaN                 2022     6'2  183lbs             94.0
# 2             NaN                 2022     5'9  150lbs             95.0
# 3             NaN                 2020     6'4  168lbs             42.0
# 4             NaN                 2023    5'11  154lbs             91.0
#
#   arrancada agilidade equilíbrio  energia  força
# 0      91.0      91.0       95.0     72.0   59.0
# 1      89.0      87.0       70.0     88.0   79.0
# 2      94.0      96.0       84.0     81.0   49.0
# 3      57.0      60.0       43.0     43.0   64.0
# 4      78.0      79.0       77.0     90.0   75.0
#
# [5 rows x 24 columns]

# %% [markdown]
# #Tipo de dados

# %% [markdown]
# ***Descoberta guiada***

# %% [markdown]
# Quais colunas são qualitativa ordinal, qualitativa nominal e quais são quantitativas contínuas e quantitativas discretas?

# %% [markdown]
# #Medidas de posição

# %% [markdown]
# ***Descoberta guiada***

# %% [markdown]
# Qual é a média e a mediana da distância das casas até o centro? Quando faz sentido usar um ou outro?

# %%
df['distanciacentro'].mean()
# Out:
# np.float64(9.65)

# %%
df['distanciacentro'].median()
# Out:
# 3.5

# %% [markdown]
# Qual é a média e mediana da renda familiar?

# %%
print(df['renda_familiar'].mean())
print(df['renda_familiar'].median())
# Out:
# 17.75
# 17.0

# %% [markdown]
# Qual é a moda em número de cartões?

# %%
df["n_cartoes"].mode()
# Out:
# 0    6
# 1    7
# 2    8
# Name: n_cartoes, dtype: int64

# %% [markdown]
# ***Handson***

# %% [markdown]
# Qual é a média de pontuação geral dos jogadores? E a mediana?

# %%
print(dffifa['pontuação geral'].mean())
print(dffifa['pontuação geral'].median())
# Out:
# 66.23869940132916
# 66.0

# %% [markdown]
# Qual é a média e a mediana da remuneração de cada jogador?

# %%
# Estratégia 1
#dffifa['remuneracao_tratado'] = dffifa['remuneração'].str.replace('€', '').str.replace('K', '').astype(float)

# Estratégia 2
dffifa['remuneracao_tratado'] = dffifa['remuneração'].str.replace('€|K', '', regex=True).astype(float) * 1000

# %%
dffifa['remuneracao_tratado'].mean()
# Out:
# np.float64(9731.312132696215)

# %%
dffifa['remuneracao_tratado'].median()
# Out:
# 3000.0

# %% [markdown]
# Qual é a moda em `remuneracao_tratado`?

# %%
dffifa['remuneracao_tratado'].mode()
# Out:
# 0    1000.0
# Name: remuneracao_tratado, dtype: float64

# %% [markdown]
# #Medidas separatizes

# %% [markdown]
# ***Descoberta guiada***

# %% [markdown]
# Quais são os quartis da distância das casas até o centro?

# %% [markdown]
# Crie um boxplot da distância das casas até o centro e interprete o que você conclui desse gráfico?

# %%
q1 = df['distanciacentro'].quantile(0.25)
print(q1)
# Out:
# 2.0

# %%
q2 = df['distanciacentro'].quantile(0.50)
print(q2)
# Out:
# 3.5

# %%
q3 = df['distanciacentro'].quantile(0.75)
print(q3)
# Out:
# 14.55

# %%
df['distanciacentro'].plot(kind = 'box')
# Out:
# <Axes: >

# %% [markdown]
# ***Handson***

# %% [markdown]
# Quais são os quartis da remuneração dos jogadores? Crie um bloxplot e interprete o gráfico.

# %%
q1 = dffifa['remuneracao_tratado'].quantile(0.25)
print(q1)
# Out:
# 1000.0

# %%
q2 = dffifa['remuneracao_tratado'].quantile(0.50)
print(q2)
# Out:
# 3000.0

# %%
q3 = dffifa['remuneracao_tratado'].quantile(0.75)
print(q3)
# Out:
# 9000.0

# %%
dffifa['remuneracao_tratado'].plot(kind = 'box')
# Out:
# <Axes: >

# %% [markdown]
# dffifa['remuneracao_tratado'].plot(kind = 'box')

# %%
Q1 = dffifa['remuneracao_tratado'].quantile(0.25)
Q3 = dffifa['remuneracao_tratado'].quantile(0.75)

IIQ = Q3 - Q1
limite_inferior = Q1 - 1.5 * IIQ
limite_superior = Q3 + 1.5 * IIQ
print("Limite inferior:", limite_inferior)
print("Limite superior:", limite_superior)
# Out:
# Limite inferior: -11000.0
# Limite superior: 21000.0

# %% [markdown]
# # Medidas de dispersão

# %% [markdown]
# ***Descoberta guiada***

# %% [markdown]
# Qual é a amplitude do número de cartões? E o desvio padrão? O que esses números dizem sobre a dispersão dos dados?

# %%
#amplitude
df['n_cartoes'].max()- df['n_cartoes'].min()
# Out:
# 6

# %%
#desvio padrão
df['n_cartoes'].std()
# Out:
# 1.7728105208558367

# %%
#coeficiente de variação
df['n_cartoes'].std() / df['n_cartoes'].mean()
# Out:
# np.float64(0.2532586458365481)

# %% [markdown]
# ***Handson***

# %% [markdown]
# Qual é a amplitude da remuneração dos jogadores da fifa? E o desvio padrão? O que esses números dizem sobre a dispersão dos dados?

# %%
#amplitude
amplitude = dffifa['remuneracao_tratado'].max()- dffifa['remuneracao_tratado'].min()
print(amplitude)
# Out:
# 565000.0

# %%
#desvio padrão
desvio_padrao = dffifa['remuneracao_tratado'].std()
print(desvio_padrao)
# Out:
# 21999.290405991298

# %%
#coeficiente de variação
dffifa['remuneracao_tratado'].std() / dffifa['remuneracao_tratado'].mean()
# Out:
# np.float64(2.260670514521462)

# %% [markdown]
# Crie uma lista com os valores:1,1,1,1,2,2,2,2 e calcule o desvio padrão? O que esse valor diz sobre a dispersão?

# %%
my_lista = [1,1,1,1,2,2,2,2]
minha_serie = pd.Series(my_lista)
minha_serie.std(ddof=0)
# Out:
# 0.5

# %% [markdown]
# #Distribuição de frequência

# %% [markdown]
# ***Descoberta guiada***

# %% [markdown]
# Crie uma tabela de frequência com valores absolutos e relativos das posições dos jogadores da fifa.

# %%
dffifa['posição'].value_counts()
# Out:
# posição
# Atacante                           2152
# Goleiro                            2025
# Zagueiro                           1778
# Meio-campista direito              1515
# Meio campista central              1394
# Lateral esquerdo                   1322
# Lateral direito                    1291
# Meio-campista esquerdo             1095
# Médio-ofensivo central              958
# Volante                             948
# Lateral direito recuado             749
# Zagueiro pela esquerda              648
# Meio campista esquerdo              395
# Meio-campista esquerdo avançado     381
# Meio-campista direito avançado      370
# Lateral esquerdo recuado            321
# Zagueiro pela direita               248
# Atacante pela esquerda              207
# Atacande pela direita               203
# Centro avante                        74
# desconhecido                         60
# Meio campista avançado esquerda      21
# Meio campista avançado direita       21
# Ponta direita                        16
# Ponta esquerda                       15
# Name: count, dtype: int64

# %%
dffifa['posição'].value_counts(normalize=True)
# Out:
# posição
# Atacante                           0.118196
# Goleiro                            0.111221
# Zagueiro                           0.097655
# Meio-campista direito              0.083210
# Meio campista central              0.076564
# Lateral esquerdo                   0.072609
# Lateral direito                    0.070907
# Meio-campista esquerdo             0.060142
# Médio-ofensivo central             0.052617
# Volante                            0.052068
# Lateral direito recuado            0.041138
# Zagueiro pela esquerda             0.035591
# Meio campista esquerdo             0.021695
# Meio-campista esquerdo avançado    0.020926
# Meio-campista direito avançado     0.020322
# Lateral esquerdo recuado           0.017631
# Zagueiro pela direita              0.013621
# Atacante pela esquerda             0.011369
# Atacande pela direita              0.011150
# Centro avante                      0.004064
# desconhecido                       0.003295
# Meio campista avançado esquerda    0.001153
# Meio campista avançado direita     0.001153
# Ponta direita                      0.000879
# Ponta esquerda                     0.000824
# Name: proportion, dtype: float64

# %% [markdown]
# Crie um gráfico de barras com os valores absolutos da posição.

# %%
dffifa['posição'].value_counts(ascending=True).plot(kind='barh')
# Out:
# <Axes: ylabel='posição'>

# %% [markdown]
# ***Handson***

# %% [markdown]
# Crie um tabela de frequência com valores absolutos e relativos do tamanho das casas

# %%
df['tamanho_casa'].value_counts(normalize=True)
# Out:
# tamanho_casa
# pequeno    0.375
# grande     0.375
# médio      0.250
# Name: proportion, dtype: float64

# %% [markdown]
# Crie um gráfico de barras com os valores dos tamanhos das casas.

# %%
df['tamanho_casa'].value_counts(ascending=True).plot(kind='bar')
# Out:
# <Axes: xlabel='tamanho_casa'>

# %% [markdown]
# #Tabela de contingência

# %% [markdown]
# ***Descoberta guiada***

# %% [markdown]
# Crie uma tabela de contingênia com as colunas de posição e perna de preferência.

# %%
pd.crosstab(dffifa['posição'], dffifa['perna de preferência'])
# Out:
# perna de preferência             Direita  Esquerda  desconhecido
# posição
# Atacande pela direita                166        37             0
# Atacante                            1859       293             0
# Atacante pela esquerda               174        33             0
# Centro avante                         56        18             0
# Goleiro                             1819       206             0
# Lateral direito                     1277        14             0
# Lateral direito recuado              713        36             0
# Lateral esquerdo                     159      1163             0
# Lateral esquerdo recuado             206       115             0
# Meio campista avançado direita        12         9             0
# Meio campista avançado esquerda       12         9             0
# Meio campista central               1145       249             0
# Meio campista esquerdo               298        97             0
# Meio-campista direito               1222       293             0
# Meio-campista direito avançado       273        97             0
# Meio-campista esquerdo               683       412             0
# Meio-campista esquerdo avançado      272       109             0
# Médio-ofensivo central               702       256             0
# Ponta direita                         10         6             0
# Ponta esquerda                        12         3             0
# Volante                              822       126             0
# Zagueiro                            1437       341             0
# Zagueiro pela direita                225        23             0
# Zagueiro pela esquerda               384       264             0
# desconhecido                          10         2            48

# %%
pd.crosstab(dffifa['posição'], dffifa['perna de preferência']).plot(kind='bar')
# Out:
# <Axes: xlabel='posição'>

# %% [markdown]
# Gere um gráfico de barras sobre os valores da tabela de contingênciada fifa, tendo o clube como x e y sendo as pernas de preferência direita, esquerda.

# %%
pd.crosstab(dffifa['time'], dffifa['perna de preferência']).plot(kind='bar')
# Out:
# <Axes: xlabel='time'>

# %% [markdown]
# ***Handson***

# %% [markdown]
# Crie uma tabela de contingência com as colunas de tamanho da casa e tipo da casa.

# %%
pd.crosstab(df['tipo_casa'], df['tamanho_casa'])
# Out:
# tamanho_casa  grande  médio  pequeno
# tipo_casa
# apartamento        2      0        1
# casa               1      1        1
# kitnet             0      0        1
# sobrado            0      1        0

# %%
pd.crosstab(df['tipo_casa'], df['tamanho_casa']).plot(kind='bar')
# Out:
# <Axes: xlabel='tipo_casa'>

# %% [markdown]
# Gere um gráfico de barras sobre os valores da tabela de contingência, tendo o tamanho da casa como x e y sendo os tipos apartamento, casa e kitnet.

# %%
pd.crosstab(df['tamanho_casa'], df['tipo_casa']).plot(kind='bar')
# Out:
# <Axes: xlabel='tamanho_casa'>

# %% [markdown]
# #Gráfico de dispersão

# %% [markdown]
# ***Descoberta guiada***

# %% [markdown]
# Gere um gráfico de dispersão considerando remuneração corrigida e pontuação geral.

# %%
import matplotlib.pyplot as plot

plot.scatter(dffifa['pontuação geral'], dffifa['remuneracao_tratado'])

# %%
dffifa.plot(x='pontuação geral', y='remuneracao_tratado', kind='scatter')
# Out:
# <Axes: xlabel='pontuação geral', ylabel='remuneracao_tratado'>

# %%
dffifa.columns
# Out:
# Index(['id', 'nome', 'idade', 'nacionalidade', 'pontuação geral', 'potencial',
#        'time', 'valor', 'remuneração', 'perna de preferência',
#        'reputação internacional', 'posição', 'camisa', 'contratação',
#        'emprestado de ', 'validade do contrato', 'altura', 'peso',
#        'controle de bola', 'arrancada', 'agilidade', 'equilíbrio', 'energia',
#        'força', 'remuneracao_tratado'],
#       dtype='object')

# %% [markdown]
# ***Handson***

# %% [markdown]
# Gere um gráfico de dispersão considerando renda familiar e número de automóveis.

# %%
df.plot(x='renda_familiar', y='num_automoveis', kind='scatter')
# Out:
# <Axes: xlabel='renda_familiar', ylabel='num_automoveis'>

# %% [markdown]
# #Correlação de pearson

# %% [markdown]
# ***Descoberta guiada***

# %% [markdown]
# Gere as correlações dos dados da fifa e busque se existem correlações fortes entre as variáveis e argumente o motivo.

# %%
dffifa_amostra = dffifa[['arrancada', 'agilidade', 'remuneracao_tratado', 'pontuação geral' ]]

dffifa_amostra
# Out:
#        arrancada  agilidade  remuneracao_tratado  pontuação geral
# 0           91.0       91.0             565000.0               94
# 1           89.0       87.0             405000.0               94
# 2           94.0       96.0             290000.0               92
# 3           57.0       60.0             260000.0               91
# 4           78.0       79.0             355000.0               91
# ...          ...        ...                  ...              ...
# 18202       54.0       60.0               1000.0               47
# 18203       41.0       38.0               1000.0               47
# 18204       70.0       50.0               1000.0               47
# 18205       61.0       52.0               1000.0               47
# 18206       57.0       55.0               1000.0               46
#
# [18207 rows x 4 columns]

# %%
dffifa_amostra.corr(method ='spearman')
# Out:
#                      arrancada  agilidade  remuneracao_tratado  \
# arrancada             1.000000   0.791570             0.165994
# agilidade             0.791570   1.000000             0.237914
# remuneracao_tratado   0.165994   0.237914             1.000000
# pontuação geral       0.189842   0.267691             0.777972
#
#                      pontuação geral
# arrancada                   0.189842
# agilidade                   0.267691
# remuneracao_tratado         0.777972
# pontuação geral             1.000000

# %%
import seaborn as sns

corr_matrix = dffifa_amostra.corr(method ='spearman')
sns.heatmap(corr_matrix, vmin= -1, vmax= +1, cmap="vlag", annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ***Handson***

# %% [markdown]
# Gere as correlações dos dados das famílias e busque se existem correlações fortes entre as variáveis e argumente o motivo.

# %%
df.columns
# Out:
# Index(['id_familia', 'tipo_casa', 'tamanho_casa', 'n_cartoes',
#        'tamanho_familia', 'renda_familiar', 'num_automoveis',
#        'distanciacentro'],
#       dtype='object')

# %%
#filtro pandas para apenas colunas numéricas

df.select_types(include = ['number']).drop(columns= 'id_familia')corr()

# %%
df_amostra = df[['n_cartoes' , 'tamanho_familia' , 'renda_familiar' , 'num_automoveis' , 'distanciacentro']]
df_amostra.corr(method ='spearman')
# Out:
#                  n_cartoes  tamanho_familia  renda_familiar  num_automoveis  \
# n_cartoes         1.000000         0.919272        0.852777        0.468295
# tamanho_familia   0.919272         1.000000        0.765490        0.335659
# renda_familiar    0.852777         0.765490        1.000000        0.548316
# num_automoveis    0.468295         0.335659        0.548316        1.000000
# distanciacentro  -0.585409        -0.343616       -0.412129       -0.076047
#
#                  distanciacentro
# n_cartoes              -0.585409
# tamanho_familia        -0.343616
# renda_familiar         -0.412129
# num_automoveis         -0.076047
# distanciacentro         1.000000

# %%
import seaborn as sns

corr_matrix = df_amostra.corr(method ='spearman')
sns.heatmap(corr_matrix, vmin= -1, vmax= +1, cmap="vlag", annot=True)
# Out:
# <Axes: >

# %% [markdown]
# #Regressão linear

# %% [markdown]
# ***Descoberta guiada***

# %% [markdown]
# Considerando os dados abaixo. Quais colunas apontam uma regressão linear entre elas?
#
# Horas praticando esporte [0,0.5,1,1.5,2,2.5,3]
#
# Humor [5,5.4,6.9,7.2,8.3,8.5,9.5]
#
# Idade[32,51,24,24,39,57,21]
#
# Filhos [1,2,1,3,1,2,4]

# %%
dados = {'horas':[0,0.5,1,1.5,2,2.5,3],
         'humor': [5,5.4,6.9,7.2,8.3,8.5,9.5],
         'idade': [32,51,24,24,39,57,21],
         'filhos': [1,2,1,3,1,2,4]
         }

df_humor = pd.DataFrame(dados)
df_humor
# Out:
#    horas  humor  idade  filhos
# 0    0.0    5.0     32       1
# 1    0.5    5.4     51       2
# 2    1.0    6.9     24       1
# 3    1.5    7.2     24       3
# 4    2.0    8.3     39       1
# 5    2.5    8.5     57       2
# 6    3.0    9.5     21       4

# %%
from sklearn.linear_model import LinearRegression

y= df_humor['humor']
X = df_humor.drop(columns = 'humor')

modelo = LinearRegression()
modelo.fit(X, y)

print(modelo.intercept_)
print(modelo.coef_)
# Out:
# 5.8587611579715455
# [ 1.65603504 -0.01693195 -0.24289803]

# %%
modelo.predict([[4, 30, 0]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([11.97494282])

# %% [markdown]
# ***Handson***

# %% [markdown]
# Considerando os dados da fifa, quais colunas podem representar uma expresão linear?

# %%
from sklearn.linear_model import LinearRegression
dffifa_amostra = dffifa_amostra.dropna()
y= dffifa_amostra['agilidade']
X = dffifa_amostra.drop(columns = 'agilidade')
modelo = LinearRegression()
modelo.fit(X, y)

print(modelo.intercept_)
print(modelo.coef_)
# Out:
# -2.998971556000612
# [ 7.80804895e-01 -4.98378582e-06  2.43022191e-01]

# %%
import statsmodels.api as sm
x = sm.add_constant(X)
results = sm.OLS(y, x).fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              agilidade   R-squared:                       0.669
# Model:                            OLS   Adj. R-squared:                  0.669
# Method:                 Least Squares   F-statistic:                 1.223e+04
# Date:                Wed, 03 Jun 2026   Prob (F-statistic):               0.00
# Time:                        00:22:48   Log-Likelihood:                -64617.
# No. Observations:               18159   AIC:                         1.292e+05
# Df Residuals:                   18155   BIC:                         1.293e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                  -2.9990      0.738     -4.062      0.000      -4.446      -1.552
# arrancada               0.7808      0.004    181.234      0.000       0.772       0.789
# remuneracao_tratado -4.984e-06   3.49e-06     -1.428      0.153   -1.18e-05    1.86e-06
# pontuação geral         0.2430      0.011     21.607      0.000       0.221       0.265
# ==============================================================================
# Omnibus:                      325.437   Durbin-Watson:                   2.008
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              564.209
# Skew:                          -0.145   Prob(JB):                    3.05e-123
# Kurtosis:                       3.813   Cond. No.                     2.82e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.82e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# #Gerando regressão linear

# %% [markdown]
# ***Descoberta guiada***

# %% [markdown]
# Encontre a fórmula da regressão linear para os dados de humor considerando horaspraticando e humor.

# %% [markdown]
# ***handson***

# %% [markdown]
# **Encontre** a fórmula da regressão linear para os dados da fifa considerando arrancada e agilidade.

# %%
dffifa_amostra = dffifa[['arrancada', 'agilidade', 'remuneracao_tratado', 'pontuação geral' ]]
dffifa_amostra.isna().sum()
# Out:
# arrancada              48
# agilidade              48
# remuneracao_tratado     0
# pontuação geral         0
# dtype: int64

# %%
dffifa_amostra = dffifa[['arrancada', 'agilidade', 'remuneracao_tratado', 'pontuação geral' ]]
dffifa_amostra = dffifa_amostra.dropna()

# %% [markdown]
# #Teste A/B amostragem

# %% [markdown]
# ***Descoberta guiada***

# %% [markdown]
# Para realizar um teste a/b para saber se a mudança do site gerou resultado, qual deve ser o tamanho de amostra considerando uma margem de erro de 2% e uma porcentagem de confiança de 95%?
#
# a) 5287
#
# b) 2401
#
# c) 8547
#
# d) 925

# %%
((1.96**2) * (.25)) / (0.02**2)
# Out:
# 2400.9999999999995

# %% [markdown]
# #Bootcamp

# %% [markdown]
# Quais análises podem ser encontradas na base de dados da Olist?
#
# Este conjunto de dados foi generosamente fornecido pela Olist, a maior loja de departamentos do mercado brasileiro. Olist conecta pequenos negócios de todo o Brasil aos canais sem burocracia e com um único contrato. Esses comerciantes podem vender seus produtos por meio da Olist Store e enviá-los diretamente aos clientes usando os parceiros de logística da Olist.
#
# Depois que um cliente compra o produto da Olist Store, um vendedor é notificado para atender a esse pedido. Assim que o cliente recebe o produto, ou a data prevista de entrega está prevista, o cliente recebe um inquérito de satisfação por e-mail onde pode dar nota da experiência de compra e deixar alguns comentários.
#
# Atenção
# Um pedido pode ter vários itens.
# Cada item pode ser atendido por um vendedor distinto.
# Todo o texto identificando lojas e parceiros foi substituído pelos nomes das grandes casas de Game of Thrones.
#
# Link para desafio Olist no kaggle:
# https://www.kaggle.com/datasets/olistbr/brazilian-ecommerce
#
# ![image.png](data:image/png,base64,...)

# %%
import pandas as pd

# dfolist_customers_dataset = pd.read_csv("https://harve.com.br/praticas/olist/olist_customers_dataset.csv")
# dfolist_customers_dataset

# dfolist_geolocation_dataset = pd.read_csv("https://harve.com.br/praticas/olist/olist_geolocation_dataset.csv")
# dfolist_geolocation_dataset

# dfolist_order_items_dataset = pd.read_csv("https://harve.com.br/praticas/olist/olist_order_items_dataset.csv")
# dfolist_order_items_dataset


dfolist_order_payments_dataset = pd.read_csv("https://harve.com.br/praticas/olist/olist_order_payments_dataset.csv")
dfolist_order_payments_dataset

# dfolist_order_reviews_dataset = pd.read_csv("https://harve.com.br/praticas/olist/olist_order_reviews_dataset.csv")
# dfolist_order_reviews_dataset

# dfolist_orders_dataset = pd.read_csv("https://harve.com.br/praticas/olist/olist_orders_dataset.csv")
# dfolist_orders_dataset


# dfolist_products_dataset = pd.read_csv("https://harve.com.br/praticas/olist/olist_products_dataset.csv")
# dfolist_products_dataset


# dfolist_sellers_dataset = pd.read_csv("https://harve.com.br/praticas/olist/olist_sellers_dataset.csv")
# dfolist_sellers_dataset


# dfproduct_category_name_translation = pd.read_csv("https://harve.com.br/praticas/olist/product_category_name_translation.csv")
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value
# 0                          8          99.33
# 1                          1          24.39
# 2                          1          65.71
# 3                          8         107.78
# 4                          2         128.45
# ...                      ...            ...
# 103881                     1         363.31
# 103882                     2          96.80
# 103883                     1          47.77
# 103884                     5         369.54
# 103885                     1         191.58
#
# [103886 rows x 5 columns]

# %%
dfolist_order_payments_dataset.plot(x='payment_installments', y = 'payment_value', kind='scatter' )
# Out:
# <Axes: xlabel='payment_installments', ylabel='payment_value'>

# %%
dfolist = dfolist_order_payments_dataset[['payment_installments', 'payment_value']]

dfolist.corr()
# Out:
#                       payment_installments  payment_value
# payment_installments              1.000000       0.330811
# payment_value                     0.330811       1.000000
